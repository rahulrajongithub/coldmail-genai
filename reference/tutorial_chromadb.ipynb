# %%
import onnxruntime
print(onnxruntime.get_available_providers())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import onnxruntime
#       2 print(onnxruntime.get_available_providers())
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\onnxruntime\__init__.py:61
#      58 from onnxruntime.capi import onnxruntime_validation
#      60 if import_capi_exception:
# ---> 61     raise import_capi_exception
#      63 from onnxruntime.capi.onnxruntime_inference_collection import (
#      64     AdapterFormat,  # noqa: F401
#      65     InferenceSession,  # noqa: F401
#    (...)     69     SparseTensor,  # noqa: F401
#      70 )
#      72 # TODO: thiagofc: Temporary experimental namespace for new PyTorch front-end
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\onnxruntime\__init__.py:24
#      14 # we need to do device version validation (for example to check Cuda version for an onnxruntime-training package).
#      15 # in order to know whether the onnxruntime package is for training it needs
#      16 # to do import onnxruntime.training.ortmodule first.
#    (...)     21 # meaningful messages to the user.
#      22 # the saved exception is raised after device version validation.
#      23 try:
# ---> 24     from onnxruntime.capi._pybind_state import (
#      25         ExecutionMode,  # noqa: F401
#      26         ExecutionOrder,  # noqa: F401
#      27         GraphOptimizationLevel,  # noqa: F401
#      28         LoraAdapter,  # noqa: F401
#      29         ModelMetadata,  # noqa: F401
#      30         NodeArg,  # noqa: F401
#      31         OrtAllocatorType,  # noqa: F401
#      32         OrtArenaCfg,  # noqa: F401
#      33         OrtMemoryInfo,  # noqa: F401
#      34         OrtMemType,  # noqa: F401
#      35         OrtSparseFormat,  # noqa: F401
#      36         RunOptions,  # noqa: F401
#      37         SessionIOBinding,  # noqa: F401
#      38         SessionOptions,  # noqa: F401
#      39         create_and_register_allocator,  # noqa: F401
#      40         create_and_register_allocator_v2,  # noqa: F401
#      41         disable_telemetry_events,  # noqa: F401
#      42         enable_telemetry_events,  # noqa: F401
#      43         get_all_providers,  # noqa: F401
#      44         get_available_providers,  # noqa: F401
#      45         get_build_info,  # noqa: F401
#      46         get_device,  # noqa: F401
#      47         get_version_string,  # noqa: F401
#      48         has_collective_ops,  # noqa: F401
#      49         set_default_logger_severity,  # noqa: F401
#      50         set_default_logger_verbosity,  # noqa: F401
#      51         set_seed,  # noqa: F401
#      52     )
#      54     import_capi_exception = None
#      55 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\onnxruntime\capi\_pybind_state.py:32
#      24         if not os.path.isfile(os.path.join(system_root, "System32", "vcruntime140_1.dll")):
#      25             warnings.warn("Please install the 2019 Visual C++ runtime and then try again. "
#      26                           "If you've installed the runtime in a non-standard location "
#      27                           "(other than %SystemRoot%\\System32), "
#      28                           "make sure it can be found by setting the correct path.")
# ---> 32 from .onnxruntime_pybind11_state import *  # noqa
#
# ImportError: DLL load failed while importing onnxruntime_pybind11_state: The specified module could not be found.

# %%
import chromadb

client = chromadb.Client()
collection = client.create_collection(name = 'my_collection')

# %%
collection.add(
    documents = [
        "This is kerala",
        "This is Russia"
    ],
    ids = ['id1', 'id2']
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:70, in ONNXMiniLM_L6_V2.__init__(self, preferred_providers)
#      68 try:
#      69     # Equivalent to import onnxruntime
# ---> 70     self.ort = importlib.import_module("onnxruntime")
#      71 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\onnxruntime\__init__.py:61
#      60 if import_capi_exception:
# ---> 61     raise import_capi_exception
#      63 from onnxruntime.capi.onnxruntime_inference_collection import (
#      64     AdapterFormat,  # noqa: F401
#      65     InferenceSession,  # noqa: F401
#    (...)     69     SparseTensor,  # noqa: F401
#      70 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\onnxruntime\__init__.py:24
#      23 try:
# ---> 24     from onnxruntime.capi._pybind_state import (
#      25         ExecutionMode,  # noqa: F401
#      26         ExecutionOrder,  # noqa: F401
#      27         GraphOptimizationLevel,  # noqa: F401
#      28         LoraAdapter,  # noqa: F401
#      29         ModelMetadata,  # noqa: F401
#      30         NodeArg,  # noqa: F401
#      31         OrtAllocatorType,  # noqa: F401
#      32         OrtArenaCfg,  # noqa: F401
#      33         OrtMemoryInfo,  # noqa: F401
#      34         OrtMemType,  # noqa: F401
#      35         OrtSparseFormat,  # noqa: F401
#      36         RunOptions,  # noqa: F401
#      37         SessionIOBinding,  # noqa: F401
#      38         SessionOptions,  # noqa: F401
#      39         create_and_register_allocator,  # noqa: F401
#      40         create_and_register_allocator_v2,  # noqa: F401
#      41         disable_telemetry_events,  # noqa: F401
#      42         enable_telemetry_events,  # noqa: F401
#      43         get_all_providers,  # noqa: F401
#      44         get_available_providers,  # noqa: F401
#      45         get_build_info,  # noqa: F401
#      46         get_device,  # noqa: F401
#      47         get_version_string,  # noqa: F401
#      48         has_collective_ops,  # noqa: F401
#      49         set_default_logger_severity,  # noqa: F401
#      50         set_default_logger_verbosity,  # noqa: F401
#      51         set_seed,  # noqa: F401
#      52     )
#      54     import_capi_exception = None
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\onnxruntime\capi\_pybind_state.py:32
#      25             warnings.warn("Please install the 2019 Visual C++ runtime and then try again. "
#      26                           "If you've installed the runtime in a non-standard location "
#      27                           "(other than %SystemRoot%\\System32), "
#      28                           "make sure it can be found by setting the correct path.")
# ---> 32 from .onnxruntime_pybind11_state import *  # noqa
#
# ImportError: DLL load failed while importing onnxruntime_pybind11_state: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 collection.add(
#       2     documents = [
#       3         "This is kerala",
#       4         "This is Russia"
#       5     ],
#       6     ids = ['id1', 'id2']
#       7 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\chromadb\api\models\Collection.py:80, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#      45 def add(
#      46     self,
#      47     ids: OneOrMany[ID],
#    (...)     57     uris: Optional[OneOrMany[URI]] = None,
#      58 ) -> None:
#      59     """Add embeddings to the data store.
#      60     Args:
#      61         ids: The ids of the embeddings you wish to add
#    (...)     77
#      78     """
# ---> 80     add_request = self._validate_and_prepare_add_request(
#      81         ids=ids,
#      82         embeddings=embeddings,
#      83         metadatas=metadatas,
#      84         documents=documents,
#      85         images=images,
#      86         uris=uris,
#      87     )
#      89     self._client._add(
#      90         collection_id=self.id,
#      91         ids=add_request["ids"],
#    (...)     97         database=self.database,
#      98     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\chromadb\api\models\CollectionCommon.py:95, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      92 @functools.wraps(func)
#      93 def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#      94     try:
# ---> 95         return func(self, *args, **kwargs)
#      96     except Exception as e:
#      97         msg = f"{str(e)} in {name}."
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\chromadb\api\models\CollectionCommon.py:236, in CollectionCommon._validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     234 if add_records["embeddings"] is None:
#     235     validate_record_set_for_embedding(record_set=add_records)
# --> 236     add_embeddings = self._embed_record_set(record_set=add_records)
#     237 else:
#     238     add_embeddings = add_records["embeddings"]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\chromadb\api\models\CollectionCommon.py:562, in CollectionCommon._embed_record_set(self, record_set, embeddable_fields)
#     558             return self._embed(
#     559                 input=self._data_loader(uris=cast(URIs, record_set[field]))  # type: ignore[literal-required]
#     560             )
#     561         else:
# --> 562             return self._embed(input=record_set[field])  # type: ignore[literal-required]
#     563 raise ValueError(
#     564     "Record does not contain any non-None fields that can be embedded."
#     565     f"Embeddable Fields: {embeddable_fields}"
#     566     f"Record Fields: {record_set}"
#     567 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\chromadb\api\models\CollectionCommon.py:575, in CollectionCommon._embed(self, input)
#     570 if self._embedding_function is None:
#     571     raise ValueError(
#     572         "You must provide an embedding function to compute embeddings."
#     573         "https://docs.trychroma.com/guides/embeddings"
#     574     )
# --> 575 return self._embedding_function(input=input)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\chromadb\api\types.py:490, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     489 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 490     result = call(self, input)
#     491     assert result is not None
#     492     return validate_embeddings(cast(Embeddings, normalize_embeddings(result)))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\chromadb\utils\embedding_functions\__init__.py:108, in DefaultEmbeddingFunction.__call__(self, input)
#     106 def __call__(self, input: Documents) -> Embeddings:
#     107     # Delegate to ONNXMiniLM_L6_V2
# --> 108     return ONNXMiniLM_L6_V2()(input)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:72, in ONNXMiniLM_L6_V2.__init__(self, preferred_providers)
#      70     self.ort = importlib.import_module("onnxruntime")
#      71 except ImportError:
# ---> 72     raise ValueError(
#      73         "The onnxruntime python package is not installed. Please install it with `pip install onnxruntime`"
#      74     )
#      75 try:
#      76     # Equivalent to from tokenizers import Tokenizer
#      77     self.Tokenizer = importlib.import_module("tokenizers").Tokenizer
#
# ValueError: The onnxruntime python package is not installed. Please install it with `pip install onnxruntime` in add.
